# %% [markdown]
# # Reconhecimento de Padrões (TIP8311) - Trabalho 1
#
#
# **Professor:** Guilherme de Alencar Barreto
#
# <img src="https://loop.frontiersin.org/images/profile/243428/203" alt="Foto do Professor" width="150"/>
#
#
# **Aluno:** Luis Felipe Carneiro de Souza    **Matrícula:** 593034

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from time import time
from pathlib import Path

# %% [markdown]
# Caminho para salvar gráficos

# %%
BASE = Path("..").resolve()
graficos = BASE / "trabalho-1" / "graficos"

# %% [markdown]
# Modelos utilizados

# %%
class KNN:
    def __init__(self, k=1, m=2):
        self.X_train = None
        self.y_train = None
        self.k = k
        self.m = m

    def fit(self, X, y):
        self.X_train = X
        self.y_train = y

    def predict(self, X):

        n_test = len(X)
        n_train = len(self.X_train)
        y_pred = []

        for i in range(n_test):

            dist = []

            for j in range(n_train):

                diff = np.abs(X[i, :] - self.X_train[j , :])
                dist.append(np.sum(diff ** (self.m)))

            dist = np.array(dist)
            idx = np.argsort(dist)[:self.k]
            neighbors, count = np.unique(self.y_train[idx], return_counts=True)
            y_pred.append(neighbors[np.argmax(count)])

        return np.array(y_pred).ravel()

# %%
class DMC:
    def __init__(self):
        self.centroides = None
        self.classes = None

    def fit(self, X, y):

        self.classes = np.sort(np.unique(y))
        self.centroides = []

        for c in self.classes:

            mask = (y == c)
            self.centroides.append(X[mask].mean(axis=0))

        self.centroides = np.array(self.centroides)

    def predict(self, X):

        n_test = len(X)
        y_pred = []

        for i in range(n_test):

            dist = []

            for c in self.centroides:

                diff = np.abs(c - X[i, :])
                dist.append(np.sum(diff ** 2))

            dist = np.array(dist)
            y_pred.append(self.classes[np.argmin(dist)])

        return np.array(y_pred).ravel()

# %%
class DMCR:
    def __init__(self):
        self.centroides = None
        self.classes = None

    def fit(self, X, y):

        self.classes = np.sort(np.unique(y))
        self.centroides = []

        for c in self.classes:

            mask = (y == c)
            self.centroides.append(np.median(X[mask], axis=0))

        self.centroides = np.array(self.centroides)

    def predict(self, X):

        n_test = len(X)
        y_pred = []

        for i in range(n_test):

            dist = []

            for c in self.centroides:

                diff = np.abs(c - X[i, :])
                dist.append(np.sum(diff))

            dist = np.array(dist)
            y_pred.append(self.classes[np.argmin(dist)])

        return np.array(y_pred).ravel()

# %%
class MaxCorr:
    def __init__(self):
        self.centroides = None
        self.classes = None

    def fit(self, X, y):

        self.classes = np.sort(np.unique(y))
        self.centroides = []

        for c in self.classes:

            mask = (y == c)
            self.centroides.append(X[mask].mean(axis=0))

        self.centroides = np.array(self.centroides)

    def predict(self, X):

        n_test = len(X)
        y_pred = []

        for i in range(n_test):

            corr_array = []

            for c in self.centroides:

                corr = np.dot(c, X[i, :])
                corr_array.append(corr)

            corr_array = np.array(corr_array)
            y_pred.append(self.classes[np.argmax(corr_array)])

        return np.array(y_pred).ravel()

# %%
class StandardScaler:
    def __init__(self):
        self.X_mu = None
        self.X_sigma = None
        self.y_mu = None
        self.y_sigma = None

    def fit(self, X, y=None):
        self.X_mu = np.mean(X, axis=0)
        self.X_sigma = np.std(X, axis=0)
        self.X_sigma = np.where(self.X_sigma == 0, 1.0, self.X_sigma)

        if y is not None:
            self.y_mu = np.mean(y, axis=0)
            self.y_sigma = np.std(y, axis=0)

    def transform(self, X, y=None):
        
        X_scaled = (X - self.X_mu) / self.X_sigma

        if y is not None:
            y_scaled = (y - self.y_mu) / self.y_sigma

        if y is None:
            return X_scaled
        else:
            return X_scaled, y_scaled

# %%
class UnitScaler:
    def __init__(self, eps=1e-12):
        self.eps = eps

    def fit(self, X, y=None):
        return self

    def transform(self, X, y=None):
        X = np.asarray(X, dtype=float)
        norms = np.linalg.norm(X, ord=2, axis=1)
        norms = np.maximum(norms, self.eps)
        return X / norms[:, None]

# %%
def accuracy_score(y_true, y_pred):
    return float(np.mean(y_true == y_pred))

# %%
def confusion_matrix(y_true, y_pred, classes):
    
    n_classes = len(classes)
    
    matriz = np.zeros((n_classes, n_classes), dtype=int)
    
    mapa_indices = {label: i for i, label in enumerate(classes)}
    
    for real, predito in zip(y_true, y_pred):
    
        linha = mapa_indices[real]
        coluna = mapa_indices[predito]
        
        matriz[linha, coluna] += 1
        
    return matriz

# %% [markdown]
# Funções auxiliares para as análises

# %%
def avaliacao(nome_modelo, modelo, X, y, test_size, n_rodadas=100):
    time_train = []
    time_test = []
    acuracias = []

    melhor_acc = -1
    pior_acc = float('inf')
    melhor_cm = None
    pior_cm = None

    classes = np.sort(np.unique(y))
    acc_p_classe = {c: [] for c in classes}

    for _ in tqdm(range(n_rodadas)):

        idx = np.random.permutation(X.shape[0])
        X, y = X[idx], y[idx]

        split = int((1 - test_size) * len(X))
        X_train, X_test = X[:split], X[split:]
        y_train, y_test = y[:split], y[split:]

        if isinstance(modelo, MaxCorr):
            scaler = UnitScaler()
        else:
            scaler = StandardScaler()
            
        scaler.fit(X_train)
        X_train_scaled = scaler.transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        # Treinamento
        t0 = time()
        modelo.fit(X_train_scaled, y_train)
        time_train.append(time() - t0)

        # Predição
        t0 = time()
        y_pred = modelo.predict(X_test_scaled)
        time_test.append(time() - t0)

        acc = accuracy_score(y_test, y_pred)
        acuracias.append(acc)

        cm = confusion_matrix(y_test, y_pred, classes)

        diagonais = cm.diagonal()
        totais_linha = cm.sum(axis=1)
        for i, c in enumerate(classes):
            if totais_linha[i] > 0:
                acc_p_classe[c].append(diagonais[i] / totais_linha[i])

        if acc > melhor_acc:
            melhor_acc = acc
            melhor_cm = cm
        if acc < pior_acc:
            pior_acc = acc
            pior_cm = cm

        resultados = {
            'modelo': nome_modelo,
            'test_size': test_size,
            'tempo_treino_medio': np.mean(time_train),
            'tempo_teste_medio': np.mean(time_test),
            'acc_media': np.mean(acuracias),
            'acc_std': np.std(acuracias),
            'acc_max': np.max(acuracias),
            'acc_min': np.min(acuracias),
            'acc_mediana': np.median(acuracias),
            'melhor_cm': melhor_cm,
            'pior_cm': pior_cm,
            'acc_por_classe': {c: np.mean(acc_p_classe[c]) for c in classes}
        }
    return resultados

# %%
def exibir_resultados(res):
    print(f"\n{'='*50}")
    print(f"Modelo: {res['modelo']} | Separação (Treino/Teste): {int((1-res['test_size'])*100)}/{int(res['test_size']*100)}")
    print(f"{'='*50}")
    print(f"Tempo Médio Treino: {res['tempo_treino_medio']:.6f}s | Tempo Médio Teste: {res['tempo_teste_medio']:.6f}s")
    print(f"Acurácia Média:   {res['acc_media']:.4f} ± {res['acc_std']:.4f}")
    print(f"Acurácia Máxima:  {res['acc_max']:.4f}")
    print(f"Acurácia Mínima:  {res['acc_min']:.4f}")
    print(f"Acurácia Mediana: {res['acc_mediana']:.4f}")
    print(f"\nAcurácia Média por Classe:")
    for c, acc in res['acc_por_classe'].items():
        print(f"  - {c}: {acc:.4f}")
    print(f"\nMelhor Matriz de Confusão:\n{res['melhor_cm']}")
    print(f"\nPior Matriz de Confusão:\n{res['pior_cm']}")

# %%
def plotar_todas_acuracias(resultados_por_modelo):
    """
    Plota a evolução da acurácia de TODOS os modelos no mesmo gráfico de linhas.
    """
    plt.figure(figsize=(12, 7))
    
    # Marcadores diferentes para diferenciar melhor as linhas
    marcadores = ['o', 's', '^', 'v', 'D', 'p', '*', 'X', '>']
    
    for i, (nome, resultados) in enumerate(resultados_por_modelo.items()):
        # Ordena por test_size para a linha não ficar embaralhada
        res_ordenados = sorted(resultados, key=lambda x: x['test_size'])
        
        x_test_sizes = [r['test_size'] * 100 for r in res_ordenados] # Em %
        y_acc = [r['acc_media'] for r in res_ordenados]
        
        plt.plot(x_test_sizes, y_acc, marker=marcadores[i % len(marcadores)], 
                 linewidth=2, markersize=8, label=nome)

    plt.title('Comparativo Geral: Efeito da Separação Treino/Teste na Acurácia', fontsize=14, pad=15)
    plt.xlabel('Porcentagem do Conjunto de Teste (%)', fontsize=12)
    plt.ylabel('Acurácia Média', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.5)
    
    # Coloca a legenda fora do gráfico para não cobrir as linhas
    plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0.)
    plt.tight_layout()
    plt.savefig(graficos / "acuracias.pdf")
    plt.show()

# %%
def plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.3):
    """
    Cria 2 subplots lado a lado comparando os tempos de Treino e Teste de todos os modelos.
    """
    nomes = list(resultados_por_modelo.keys())
    tempos_treino = []
    tempos_teste = []
    
    for nome in nomes:
        # Busca o resultado específico para a proporção escolhida (ex: 30% teste)
        res_foco = next(r for r in resultados_por_modelo[nome] if r['test_size'] == test_size_foco)
        tempos_treino.append(res_foco['tempo_treino_medio'])
        tempos_teste.append(res_foco['tempo_teste_medio'])

    # Cria a figura com 2 subplots lado a lado
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))

    # Gráfico 1: Treino
    ax1.barh(nomes, tempos_treino, color='#55A868', edgecolor='black')
    ax1.set_title(f'Tempo de Treinamento (Teste: {int(test_size_foco*100)}%)', fontsize=12)
    ax1.set_xlabel('Segundos')
    ax1.invert_yaxis() # Inverte para o primeiro modelo ficar no topo
    ax1.grid(axis='x', linestyle='--', alpha=0.7)

    # Gráfico 2: Teste
    # Usamos escala logarítmica (opcional) caso o KNN seja absurdamente mais lento que os centróides
    ax2.barh(nomes, tempos_teste, color='#C44E52', edgecolor='black')
    ax2.set_title(f'Tempo de Teste (Teste: {int(test_size_foco*100)}%)', fontsize=12)
    ax2.set_xlabel('Segundos')
    ax2.invert_yaxis()
    ax2.grid(axis='x', linestyle='--', alpha=0.7)

    plt.tight_layout()
    plt.savefig(graficos / f"tempos_{('').join(str(test_size_foco).split('.'))}.pdf")
    plt.show()

# %%
def plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.3, tipo='melhor_cm'):
    """
    Cria um grid 3x3 com as matrizes de confusão da melhor rodada de cada modelo.
    """
    nomes = list(resultados_por_modelo.keys())
    
    # Cria uma figura 3x3
    fig, axes = plt.subplots(3, 3, figsize=(12, 12))
    axes = axes.flatten() # Transforma a matriz de eixos num array 1D para facilitar o loop
    
    for i, nome in enumerate(nomes):
        if i >= 9: break # Garante que não vai estourar o limite de 9 subplots
        
        ax = axes[i]
        res_foco = next(r for r in resultados_por_modelo[nome] if r['test_size'] == test_size_foco)
        cm = res_foco[tipo]
        
        # Plota o heatmap da matriz
        if tipo == 'melhor_cm':
            cmap = 'Blues'
        else:
            cmap = 'Reds'
        cax = ax.matshow(cm, cmap=cmap, alpha=0.8)
        ax.set_title(nome, pad=10, fontsize=11, fontweight='bold')
        
        # Oculta os eixos para ficar mais limpo
        ax.set_xticks([])
        ax.set_yticks([])
        
        # Adiciona os números nos quadrados
        limite = cm.max() / 2.
        for (y, x), val in np.ndenumerate(cm):
            ax.text(x, y, f"{val}", ha='center', va='center',
                    color='white' if val > limite else 'black', fontsize=10)

    # Adiciona um título geral para a figura
    fig.suptitle(f'Melhores Matrizes de Confusão por Modelo (Teste: {int(test_size_foco*100)}%)', 
                 fontsize=16, y=0.98)
    plt.tight_layout()
    plt.savefig(graficos / f"{tipo}_{('').join(str(test_size_foco).split('.'))}.pdf")
    plt.show()

# %%
def plotar_grid_acuracias_std_mediana(resultados_por_modelo):
    """
    Cria um grid 3x3 plotando a evolução da acurácia (média e mediana) 
    e o desvio padrão de forma isolada para cada modelo.
    """
    nomes = list(resultados_por_modelo.keys())
    
    # Cria uma figura 3x3, compartilhando o eixo Y
    fig, axes = plt.subplots(3, 3, figsize=(14, 12), sharey=True)
    axes = axes.flatten() 
    
    for i, (nome, resultados) in enumerate(resultados_por_modelo.items()):
        if i >= 9: break 
        
        ax = axes[i]
        
        # Ordena os dados pelo tamanho do teste
        res_ordenados = sorted(resultados, key=lambda x: x['test_size'])
        
        x_test_sizes = [r['test_size'] * 100 for r in res_ordenados] # Eixo X em %
        y_acc_media = np.array([r['acc_media'] for r in res_ordenados])    # Média
        y_acc_mediana = np.array([r['acc_mediana'] for r in res_ordenados]) # Mediana
        y_std = np.array([r['acc_std'] for r in res_ordenados])            # Desvio Padrão
        
        # 1. Plota a linha da Média (azul, sólida)
        linha_media, = ax.plot(x_test_sizes, y_acc_media, marker='o', color='#1F77B4', 
                               linewidth=2, markersize=6, label='Média')
        
        # 2. Plota a sombra do Desvio Padrão
        ax.fill_between(x_test_sizes, y_acc_media - y_std, y_acc_media + y_std, 
                        color='#1F77B4', alpha=0.25, label='Desvio Padrão (±1 std)')
        
        # 3. Plota a linha da Mediana (vermelha, tracejada)
        linha_mediana, = ax.plot(x_test_sizes, y_acc_mediana, marker='s', color='#D62728', 
                                 linewidth=2, linestyle='--', markersize=5, label='Mediana')
        
        # Formatação individual do subplot
        ax.set_title(nome, fontsize=12, fontweight='bold', color='#333333')
        ax.set_xticks(x_test_sizes) 
        ax.grid(True, linestyle='--', alpha=0.6)
        
        # Adiciona rótulos de eixo nas bordas
        if i >= 6: 
            ax.set_xlabel('Conjunto de Teste (%)', fontsize=10)
        if i % 3 == 0:
            ax.set_ylabel('Acurácia', fontsize=10)

    # Título principal da figura inteira
    # fig.suptitle('Evolução da Acurácia (Média vs Mediana) e Desvio Padrão por Modelo', 
    #              fontsize=16, y=0.98, fontweight='bold')
    
    # Adiciona uma única legenda global no topo da figura para não poluir os subplots
    linhas = [linha_media, linha_mediana]
    labels = ['Acurácia Média', 'Acurácia Mediana']
    fig.legend(linhas, labels, loc='upper right', bbox_to_anchor=(0.95, 0.98), 
               ncol=2, fontsize=11, frameon=True)

    plt.tight_layout()
    # Ajusta o espaçamento para o título e a legenda caberem perfeitamente
    plt.subplots_adjust(top=0.90)
    plt.savefig(graficos / "acuracias.pdf")
    plt.show()

# %% [markdown]
# ## **Questão 1 (Classificação de Padrões)**
#
# Objetivo: Abordar o clássico problema de classificação de patologias da coluna vertebral. O banco de dados está disponível no site abaixo:
#
# https://archive.ics.uci.edu/dataset/212/vertebral+column
#
# Usando o problema com 3 classes, implementar e avaliar os classificadores estudados na disciplina, listados abaixo
#
# Classificadores a Implementar
# 1. Classificador Vizinho Mais Próximo (distância de Minkowski de ordens $m \in {0,5; 2/3; 1; 3/2; 2; 5;2}$ )
# 2. Classificador Distância Mínima ao Centróide
# 3. Classificador Distância Mínima ao Centróide (versão robusta a outliers)
# 4. Classificador de Máxima Correlação
#
# **OBS 1**: Computar os tempos de treinamento e teste de cada modelo para ajudar a decidir pelo melhor modelo.
#
# **OBS 2**: Realizar, no mínimo, 100 rodadas de treinamento-teste independentes dos modelos e obter as estatísticas de desempenho (acurácia média, desvio-padrão, acurácia máxima, acurácia mínima e mediana da acurácia). Determinar a matriz de confusão para a melhor e pior rodada.
#
# **OBS 3**:  Avaliar   o   efeito   da   porcentagem   de   separação   dos   dados   de   treino-teste   no   desempenho   dos classificadores. Sugestão: testar as seguintes possibilidades: 20/80, 30/70, 50/50, 70/30 e 80/20.
#
# **OBS 4**: Calcular também as estatísticas de desempenho por classe, com o objetivo de entender se há classes mais fáceis de categorizar que outras. Boa sorte!

# %%
data_path = "vertebral+column\column_3C.dat"

data = np.genfromtxt(fname=data_path, delimiter=None, dtype=str, encoding='utf-8')
data

X = data[:, :-1].astype(float) 
y = data[:, -1]

# %%
proporcoes_teste = [0.8, 0.7, 0.5, 0.3, 0.2]

# Distâncias de Minkowski para o KNN: m in {0.5, 2/3, 1, 1.5, 2, 5}
m_values = [0.5, 2/3, 1.0, 1.5, 2.0, 5.0]

resultados_por_modelo = {}

# %% [markdown]
# ### Classificador Vizinho Mais Próximo (distância de Minkowski de ordens m ∈ {0,5; 2/3; 1; 3/2; 2; 5/2})

# %%
modelos_para_testar = {f"KNN (m={m:.2f})": KNN(k=1, m=m) for m in m_values}

# %%
for nome, modelo in modelos_para_testar.items():
    print(f"\n{'='*60}")
    print(f"AVALIANDO O MODELO: {nome}")
    print(f"{'='*60}")
    
    # Inicializa uma lista vazia para guardar os resultados das diferentes partições deste modelo
    resultados_por_modelo[nome] = []
    
    for proporcao in proporcoes_teste:
        print(f"  -> Rodando com Test Size = {proporcao*100}%...")
        
        # Chama a função de avaliação que nós corrigimos anteriormente
        res = avaliacao(nome_modelo=nome, modelo=modelo, X=X, y=y, test_size=proporcao, n_rodadas=100)
        
        # Salva o resultado
        resultados_por_modelo[nome].append(res)
# Out:
# ============================================================
# AVALIANDO O MODELO: KNN (m=0.50)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.99it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 18.78it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 15.86it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 19.20it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:03<00:00, 25.16it/s]
# ============================================================
# AVALIANDO O MODELO: KNN (m=0.67)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 22.55it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.27it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 14.56it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.49it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.05it/s]
# ============================================================
# AVALIANDO O MODELO: KNN (m=1.00)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 22.79it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.64it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 14.90it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.79it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.29it/s]
# ============================================================
# AVALIANDO O MODELO: KNN (m=1.50)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 22.68it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.40it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 14.83it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.67it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.40it/s]
# ============================================================
# AVALIANDO O MODELO: KNN (m=2.00)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.02it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.76it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 14.99it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.94it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.72it/s]
# ============================================================
# AVALIANDO O MODELO: KNN (m=5.00)
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:04<00:00, 22.52it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.37it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:06<00:00, 14.64it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:05<00:00, 17.56it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:04<00:00, 23.01it/s]

# %% [markdown]
# ### Classificador Distância Mínima ao Centróide

# %%
modelos_para_testar.update({
    "DMC": DMC()
    })

print(f"\n{'='*60}")
print(f"AVALIANDO O MODELO: {'DMC'}")
print(f"{'='*60}")

# Inicializa uma lista vazia para guardar os resultados das diferentes partições deste modelo
resultados_por_modelo["DMC"] = []

for proporcao in proporcoes_teste:
    print(f"  -> Rodando com Test Size = {proporcao*100}%...")
    
    # Chama a função de avaliação que nós corrigimos anteriormente
    res = avaliacao(nome_modelo="DMC", modelo=DMC(), X=X, y=y, test_size=proporcao, n_rodadas=100)
    # exibir_resultados(res)
    # Salva o resultado
    resultados_por_modelo["DMC"].append(res)
# Out:
# ============================================================
# AVALIANDO O MODELO: DMC
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:00<00:00, 385.28it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:00<00:00, 441.18it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:00<00:00, 567.26it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:00<00:00, 896.14it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:00<00:00, 1256.36it/s]

# %% [markdown]
# ### Classificador Distância Mínima ao Centróide (versão robusta a outliers)

# %%
modelos_para_testar.update({
    "DMCR": DMCR()
    })

print(f"\n{'='*60}")
print(f"AVALIANDO O MODELO: {'DMCR'}")
print(f"{'='*60}")

# Inicializa uma lista vazia para guardar os resultados das diferentes partições deste modelo
resultados_por_modelo["DMCR"] = []

for proporcao in proporcoes_teste:
    print(f"  -> Rodando com Test Size = {proporcao*100}%...")
    
    # Chama a função de avaliação que nós corrigimos anteriormente
    res = avaliacao(nome_modelo="DMCR", modelo=DMCR(), X=X, y=y, test_size=proporcao, n_rodadas=100)
    # exibir_resultados(res)
    # Salva o resultado
    resultados_por_modelo["DMCR"].append(res)
# Out:
# ============================================================
# AVALIANDO O MODELO: DMCR
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:00<00:00, 417.48it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:00<00:00, 476.73it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:00<00:00, 608.09it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:00<00:00, 875.23it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:00<00:00, 1282.47it/s]

# %% [markdown]
# ### Classificador de Máxima Correlação

# %%
modelos_para_testar.update({
    "MaxCorr": MaxCorr()
    })

print(f"\n{'='*60}")
print(f"AVALIANDO O MODELO: {'MaxCorr'}")
print(f"{'='*60}")

# Inicializa uma lista vazia para guardar os resultados das diferentes partições deste modelo
resultados_por_modelo["MaxCorr"] = []

for proporcao in proporcoes_teste:
    print(f"  -> Rodando com Test Size = {proporcao*100}%...")
    
    # Chama a função de avaliação que nós corrigimos anteriormente
    res = avaliacao(nome_modelo="MaxCorr", modelo=MaxCorr(), X=X, y=y, test_size=proporcao, n_rodadas=100)
    # exibir_resultados(res)
    # Salva o resultado
    resultados_por_modelo["MaxCorr"].append(res)
# Out:
# ============================================================
# AVALIANDO O MODELO: MaxCorr
# ============================================================
#   -> Rodando com Test Size = 80.0%...
# 100%|██████████| 100/100 [00:00<00:00, 891.70it/s]
#   -> Rodando com Test Size = 70.0%...
# 100%|██████████| 100/100 [00:00<00:00, 1009.51it/s]
#   -> Rodando com Test Size = 50.0%...
# 100%|██████████| 100/100 [00:00<00:00, 1272.68it/s]
#   -> Rodando com Test Size = 30.0%...
# 100%|██████████| 100/100 [00:00<00:00, 1949.82it/s]
#   -> Rodando com Test Size = 20.0%...
# 100%|██████████| 100/100 [00:00<00:00, 2094.55it/s]

# %% [markdown]
# Sintese dos resultados

# %%
plotar_grid_acuracias_std_mediana(resultados_por_modelo)

# %%
plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.2)

# %%
plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.3)

# %%
plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.5)

# %%
plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.7)

# %%
plotar_tempos_condensados(resultados_por_modelo, test_size_foco=0.8)

# %%
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.2 ,tipo="melhor_cm")
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.2 ,tipo="pior_cm")

# %%
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.3 ,tipo="melhor_cm")
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.3 ,tipo="pior_cm")

# %%
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.5 ,tipo="melhor_cm")
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.5 ,tipo="pior_cm")

# %%
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.7 ,tipo="melhor_cm")
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.7 ,tipo="pior_cm")

# %%
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.8 ,tipo="melhor_cm")
plotar_grid_matrizes(resultados_por_modelo, test_size_foco=0.8 ,tipo="pior_cm")

# %%
for chave in resultados_por_modelo.keys():
    for resultado in resultados_por_modelo[chave]:
        exibir_resultados(resultado)
# Out:
# ==================================================
# Modelo: KNN (m=0.50) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.040978s
# Acurácia Média:   0.7251 ± 0.0306
# Acurácia Máxima:  0.7952
# Acurácia Mínima:  0.6386
# Acurácia Mediana: 0.7269
#
# Acurácia Média por Classe:
#   - DH: 0.5302
#   - NO: 0.6565
#   - SL: 0.8530
#
# Melhor Matriz de Confusão:
# [[ 31  11   1]
#  [ 15  59   9]
#  [  6   9 108]]
#
# Pior Matriz de Confusão:
# [[ 24  19   1]
#  [ 38  31  16]
#  [  8   8 104]]
#
# ==================================================
# Modelo: KNN (m=0.50) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.052533s
# Acurácia Média:   0.7346 ± 0.0260
# Acurácia Máxima:  0.8065
# Acurácia Mínima:  0.6682
# Acurácia Mediana: 0.7327
#
# Acurácia Média por Classe:
#   - DH: 0.5405
#   - NO: 0.6832
#   - SL: 0.8496
#
# Melhor Matriz de Confusão:
# [[27 13  1]
#  [ 8 56  5]
#  [ 1 14 92]]
#
# Pior Matriz de Confusão:
# [[18 23  3]
#  [14 45  9]
#  [ 2 21 82]]
#
# ==================================================
# Modelo: KNN (m=0.50) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.062387s
# Acurácia Média:   0.7413 ± 0.0257
# Acurácia Máxima:  0.8065
# Acurácia Mínima:  0.6774
# Acurácia Mediana: 0.7355
#
# Acurácia Média por Classe:
#   - DH: 0.5678
#   - NO: 0.6925
#   - SL: 0.8472
#
# Melhor Matriz de Confusão:
# [[22  9  0]
#  [ 5 33  4]
#  [ 3  9 70]]
#
# Pior Matriz de Confusão:
# [[15 12  0]
#  [11 36  7]
#  [ 8 12 54]]
#
# ==================================================
# Modelo: KNN (m=0.50) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.051523s
# Acurácia Média:   0.7445 ± 0.0388
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.6452
# Acurácia Mediana: 0.7527
#
# Acurácia Média por Classe:
#   - DH: 0.5455
#   - NO: 0.7334
#   - SL: 0.8363
#
# Melhor Matriz de Confusão:
# [[10  6  1]
#  [ 3 22  2]
#  [ 1  2 46]]
#
# Pior Matriz de Confusão:
# [[ 7  8  2]
#  [14 19  3]
#  [ 1  5 34]]
#
# ==================================================
# Modelo: KNN (m=0.50) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.039261s
# Acurácia Média:   0.7534 ± 0.0494
# Acurácia Máxima:  0.8871
# Acurácia Mínima:  0.5968
# Acurácia Mediana: 0.7581
#
# Acurácia Média por Classe:
#   - DH: 0.5622
#   - NO: 0.7211
#   - SL: 0.8471
#
# Melhor Matriz de Confusão:
# [[11  3  0]
#  [ 1 15  0]
#  [ 1  2 29]]
#
# Pior Matriz de Confusão:
# [[ 5  5  1]
#  [ 4 10  4]
#  [ 1 10 22]]
#
# ==================================================
# Modelo: KNN (m=0.67) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.043795s
# Acurácia Média:   0.7286 ± 0.0268
# Acurácia Máxima:  0.7791
# Acurácia Mínima:  0.6546
# Acurácia Mediana: 0.7309
#
# Acurácia Média por Classe:
#   - DH: 0.5212
#   - NO: 0.6712
#   - SL: 0.8527
#
# Melhor Matriz de Confusão:
# [[ 33  12   0]
#  [ 19  52  11]
#  [  4   9 109]]
#
# Pior Matriz de Confusão:
# [[20 26  3]
#  [14 60  3]
#  [ 4 36 83]]
#
# ==================================================
# Modelo: KNN (m=0.67) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000010s | Tempo Médio Teste: 0.057207s
# Acurácia Média:   0.7426 ± 0.0245
# Acurácia Máxima:  0.7926
# Acurácia Mínima:  0.6774
# Acurácia Mediana: 0.7396
#
# Acurácia Média por Classe:
#   - DH: 0.5617
#   - NO: 0.6804
#   - SL: 0.8602
#
# Melhor Matriz de Confusão:
# [[24 15  0]
#  [ 8 53 10]
#  [ 3  9 95]]
#
# Pior Matriz de Confusão:
# [[19 21  2]
#  [16 48  6]
#  [ 1 24 80]]
#
# ==================================================
# Modelo: KNN (m=0.67) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.068020s
# Acurácia Média:   0.7537 ± 0.0327
# Acurácia Máxima:  0.8258
# Acurácia Mínima:  0.6581
# Acurácia Mediana: 0.7548
#
# Acurácia Média por Classe:
#   - DH: 0.5644
#   - NO: 0.7199
#   - SL: 0.8562
#
# Melhor Matriz de Confusão:
# [[16 12  3]
#  [ 8 35  2]
#  [ 0  2 77]]
#
# Pior Matriz de Confusão:
# [[13 19  4]
#  [ 8 30  2]
#  [ 6 14 59]]
#
# ==================================================
# Modelo: KNN (m=0.67) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.056531s
# Acurácia Média:   0.7530 ± 0.0398
# Acurácia Máxima:  0.8280
# Acurácia Mínima:  0.6452
# Acurácia Mediana: 0.7527
#
# Acurácia Média por Classe:
#   - DH: 0.5813
#   - NO: 0.7258
#   - SL: 0.8443
#
# Melhor Matriz de Confusão:
# [[11  5  0]
#  [ 4 16  2]
#  [ 1  4 50]]
#
# Pior Matriz de Confusão:
# [[ 5 12  0]
#  [10 18  4]
#  [ 1  6 37]]
#
# ==================================================
# Modelo: KNN (m=0.67) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.042857s
# Acurácia Média:   0.7582 ± 0.0472
# Acurácia Máxima:  0.8548
# Acurácia Mínima:  0.5645
# Acurácia Mediana: 0.7581
#
# Acurácia Média por Classe:
#   - DH: 0.5560
#   - NO: 0.7549
#   - SL: 0.8414
#
# Melhor Matriz de Confusão:
# [[ 7  4  0]
#  [ 0 10  4]
#  [ 0  1 36]]
#
# Pior Matriz de Confusão:
# [[ 5 11  0]
#  [ 5 16  1]
#  [ 2  8 14]]
#
# ==================================================
# Modelo: KNN (m=1.00) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000010s | Tempo Médio Teste: 0.043405s
# Acurácia Média:   0.7367 ± 0.0296
# Acurácia Máxima:  0.8112
# Acurácia Mínima:  0.6426
# Acurácia Mediana: 0.7390
#
# Acurácia Média por Classe:
#   - DH: 0.5380
#   - NO: 0.6722
#   - SL: 0.8625
#
# Melhor Matriz de Confusão:
# [[ 23  24   0]
#  [  3  71   4]
#  [  4  12 108]]
#
# Pior Matriz de Confusão:
# [[25 23  1]
#  [31 45  8]
#  [ 9 17 90]]
#
# ==================================================
# Modelo: KNN (m=1.00) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.056113s
# Acurácia Média:   0.7493 ± 0.0314
# Acurácia Máxima:  0.8249
# Acurácia Mínima:  0.6682
# Acurácia Mediana: 0.7465
#
# Acurácia Média por Classe:
#   - DH: 0.5709
#   - NO: 0.6833
#   - SL: 0.8697
#
# Melhor Matriz de Confusão:
# [[30 10  0]
#  [20 51  3]
#  [ 1  4 98]]
#
# Pior Matriz de Confusão:
# [[15 25  5]
#  [15 45  4]
#  [ 3 20 85]]
#
# ==================================================
# Modelo: KNN (m=1.00) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.066442s
# Acurácia Média:   0.7575 ± 0.0293
# Acurácia Máxima:  0.8452
# Acurácia Mínima:  0.6839
# Acurácia Mediana: 0.7548
#
# Acurácia Média por Classe:
#   - DH: 0.5615
#   - NO: 0.7169
#   - SL: 0.8674
#
# Melhor Matriz de Confusão:
# [[17  7  1]
#  [ 7 40  4]
#  [ 1  4 74]]
#
# Pior Matriz de Confusão:
# [[11 18  1]
#  [ 9 35  9]
#  [ 2 10 60]]
#
# ==================================================
# Modelo: KNN (m=1.00) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.055549s
# Acurácia Média:   0.7734 ± 0.0369
# Acurácia Máxima:  0.8710
# Acurácia Mínima:  0.6882
# Acurácia Mediana: 0.7742
#
# Acurácia Média por Classe:
#   - DH: 0.6308
#   - NO: 0.7223
#   - SL: 0.8639
#
# Melhor Matriz de Confusão:
# [[12  4  0]
#  [ 3 22  2]
#  [ 0  3 47]]
#
# Pior Matriz de Confusão:
# [[ 8  2  2]
#  [ 7 18  5]
#  [ 2 11 38]]
#
# ==================================================
# Modelo: KNN (m=1.00) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.042453s
# Acurácia Média:   0.7890 ± 0.0422
# Acurácia Máxima:  0.8871
# Acurácia Mínima:  0.7097
# Acurácia Mediana: 0.7903
#
# Acurácia Média por Classe:
#   - DH: 0.6326
#   - NO: 0.7541
#   - SL: 0.8769
#
# Melhor Matriz de Confusão:
# [[ 8  2  0]
#  [ 2 15  1]
#  [ 0  2 32]]
#
# Pior Matriz de Confusão:
# [[ 9  5  0]
#  [ 4 13  3]
#  [ 3  3 22]]
#
# ==================================================
# Modelo: KNN (m=1.50) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.043633s
# Acurácia Média:   0.7400 ± 0.0339
# Acurácia Máxima:  0.8313
# Acurácia Mínima:  0.6627
# Acurácia Mediana: 0.7390
#
# Acurácia Média por Classe:
#   - DH: 0.5148
#   - NO: 0.6768
#   - SL: 0.8754
#
# Melhor Matriz de Confusão:
# [[ 34  15   1]
#  [ 14  60   7]
#  [  0   5 113]]
#
# Pior Matriz de Confusão:
# [[19 33  1]
#  [13 54  9]
#  [ 5 23 92]]
#
# ==================================================
# Modelo: KNN (m=1.50) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.056829s
# Acurácia Média:   0.7443 ± 0.0311
# Acurácia Máxima:  0.8157
# Acurácia Mínima:  0.6590
# Acurácia Mediana: 0.7465
#
# Acurácia Média por Classe:
#   - DH: 0.5545
#   - NO: 0.6806
#   - SL: 0.8668
#
# Melhor Matriz de Confusão:
# [[27 13  0]
#  [13 51  4]
#  [ 3  7 99]]
#
# Pior Matriz de Confusão:
# [[14 31  1]
#  [ 8 48 12]
#  [ 6 16 81]]
#
# ==================================================
# Modelo: KNN (m=1.50) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.066807s
# Acurácia Média:   0.7716 ± 0.0331
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.6839
# Acurácia Mediana: 0.7677
#
# Acurácia Média por Classe:
#   - DH: 0.5921
#   - NO: 0.7273
#   - SL: 0.8758
#
# Melhor Matriz de Confusão:
# [[25  7  1]
#  [ 8 34  4]
#  [ 2  3 71]]
#
# Pior Matriz de Confusão:
# [[15 13  3]
#  [16 35  4]
#  [ 2 11 56]]
#
# ==================================================
# Modelo: KNN (m=1.50) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.055945s
# Acurácia Média:   0.7851 ± 0.0379
# Acurácia Máxima:  0.8925
# Acurácia Mínima:  0.6882
# Acurácia Mediana: 0.7849
#
# Acurácia Média por Classe:
#   - DH: 0.6183
#   - NO: 0.7529
#   - SL: 0.8785
#
# Melhor Matriz de Confusão:
# [[12  2  1]
#  [ 4 27  1]
#  [ 1  1 44]]
#
# Pior Matriz de Confusão:
# [[12  8  1]
#  [ 8 18  5]
#  [ 1  6 34]]
#
# ==================================================
# Modelo: KNN (m=1.50) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.042256s
# Acurácia Média:   0.7992 ± 0.0509
# Acurácia Máxima:  0.9194
# Acurácia Mínima:  0.6613
# Acurácia Mediana: 0.7903
#
# Acurácia Média por Classe:
#   - DH: 0.6388
#   - NO: 0.7651
#   - SL: 0.8884
#
# Melhor Matriz de Confusão:
# [[ 8  0  1]
#  [ 1 14  1]
#  [ 0  2 35]]
#
# Pior Matriz de Confusão:
# [[ 6  7  1]
#  [ 2 11  6]
#  [ 1  4 24]]
#
# ==================================================
# Modelo: KNN (m=2.00) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.042862s
# Acurácia Média:   0.7393 ± 0.0355
# Acurácia Máxima:  0.8193
# Acurácia Mínima:  0.6345
# Acurácia Mediana: 0.7430
#
# Acurácia Média por Classe:
#   - DH: 0.5506
#   - NO: 0.6617
#   - SL: 0.8713
#
# Melhor Matriz de Confusão:
# [[ 30   9   0]
#  [ 15  68   2]
#  [  6  13 106]]
#
# Pior Matriz de Confusão:
# [[13 34  7]
#  [13 47 26]
#  [ 4  7 98]]
#
# ==================================================
# Modelo: KNN (m=2.00) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.055587s
# Acurácia Média:   0.7535 ± 0.0280
# Acurácia Máxima:  0.8018
# Acurácia Mínima:  0.6820
# Acurácia Mediana: 0.7558
#
# Acurácia Média por Classe:
#   - DH: 0.5533
#   - NO: 0.6924
#   - SL: 0.8776
#
# Melhor Matriz de Confusão:
# [[24 19  1]
#  [ 8 54  4]
#  [ 3  8 96]]
#
# Pior Matriz de Confusão:
# [[26 11  1]
#  [26 40  8]
#  [ 7 16 82]]
#
# ==================================================
# Modelo: KNN (m=2.00) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.066164s
# Acurácia Média:   0.7725 ± 0.0324
# Acurácia Máxima:  0.8710
# Acurácia Mínima:  0.6774
# Acurácia Mediana: 0.7742
#
# Acurácia Média por Classe:
#   - DH: 0.5884
#   - NO: 0.7180
#   - SL: 0.8875
#
# Melhor Matriz de Confusão:
# [[23  3  1]
#  [ 6 43  2]
#  [ 3  5 69]]
#
# Pior Matriz de Confusão:
# [[11 22  5]
#  [ 8 39  7]
#  [ 2  6 55]]
#
# ==================================================
# Modelo: KNN (m=2.00) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.055149s
# Acurácia Média:   0.7941 ± 0.0399
# Acurácia Máxima:  0.8710
# Acurácia Mínima:  0.6667
# Acurácia Mediana: 0.7957
#
# Acurácia Média por Classe:
#   - DH: 0.6017
#   - NO: 0.7712
#   - SL: 0.8869
#
# Melhor Matriz de Confusão:
# [[14  1  0]
#  [ 6 26  3]
#  [ 0  2 41]]
#
# Pior Matriz de Confusão:
# [[10  7  0]
#  [ 8 17  3]
#  [ 3 10 35]]
#
# ==================================================
# Modelo: KNN (m=2.00) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.041685s
# Acurácia Média:   0.7939 ± 0.0486
# Acurácia Máxima:  0.9032
# Acurácia Mínima:  0.6613
# Acurácia Mediana: 0.8065
#
# Acurácia Média por Classe:
#   - DH: 0.6078
#   - NO: 0.7746
#   - SL: 0.8817
#
# Melhor Matriz de Confusão:
# [[ 8  2  0]
#  [ 2 14  0]
#  [ 1  1 34]]
#
# Pior Matriz de Confusão:
# [[ 5 12  1]
#  [ 1 13  3]
#  [ 0  4 23]]
#
# ==================================================
# Modelo: KNN (m=5.00) | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.043860s
# Acurácia Média:   0.7314 ± 0.0352
# Acurácia Máxima:  0.8032
# Acurácia Mínima:  0.6546
# Acurácia Mediana: 0.7329
#
# Acurácia Média por Classe:
#   - DH: 0.5198
#   - NO: 0.6526
#   - SL: 0.8731
#
# Melhor Matriz de Confusão:
# [[ 27  22   1]
#  [  9  61   3]
#  [  3  11 112]]
#
# Pior Matriz de Confusão:
# [[ 24  16   8]
#  [ 27  36  22]
#  [  2  11 103]]
#
# ==================================================
# Modelo: KNN (m=5.00) | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.056921s
# Acurácia Média:   0.7472 ± 0.0331
# Acurácia Máxima:  0.8249
# Acurácia Mínima:  0.6636
# Acurácia Mediana: 0.7465
#
# Acurácia Média por Classe:
#   - DH: 0.5348
#   - NO: 0.6787
#   - SL: 0.8827
#
# Melhor Matriz de Confusão:
# [[33  9  4]
#  [13 55  3]
#  [ 1  8 91]]
#
# Pior Matriz de Confusão:
# [[22 12  1]
#  [32 37 13]
#  [ 5 10 85]]
#
# ==================================================
# Modelo: KNN (m=5.00) | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.067679s
# Acurácia Média:   0.7634 ± 0.0290
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.6839
# Acurácia Mediana: 0.7677
#
# Acurácia Média por Classe:
#   - DH: 0.5616
#   - NO: 0.6975
#   - SL: 0.8908
#
# Melhor Matriz de Confusão:
# [[17  7  1]
#  [ 6 38  4]
#  [ 3  4 75]]
#
# Pior Matriz de Confusão:
# [[15 21  4]
#  [ 9 30  7]
#  [ 3  5 61]]
#
# ==================================================
# Modelo: KNN (m=5.00) | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000000s | Tempo Médio Teste: 0.056296s
# Acurácia Média:   0.7756 ± 0.0389
# Acurácia Máxima:  0.8817
# Acurácia Mínima:  0.6667
# Acurácia Mediana: 0.7742
#
# Acurácia Média por Classe:
#   - DH: 0.5816
#   - NO: 0.7115
#   - SL: 0.8997
#
# Melhor Matriz de Confusão:
# [[12  2  0]
#  [ 6 22  2]
#  [ 0  1 48]]
#
# Pior Matriz de Confusão:
# [[10  9  4]
#  [ 7 24  8]
#  [ 1  2 28]]
#
# ==================================================
# Modelo: KNN (m=5.00) | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000010s | Tempo Médio Teste: 0.043039s
# Acurácia Média:   0.7748 ± 0.0485
# Acurácia Máxima:  0.8710
# Acurácia Mínima:  0.6452
# Acurácia Mediana: 0.7742
#
# Acurácia Média por Classe:
#   - DH: 0.5557
#   - NO: 0.7336
#   - SL: 0.8927
#
# Melhor Matriz de Confusão:
# [[ 6  1  0]
#  [ 3 19  1]
#  [ 0  3 29]]
#
# Pior Matriz de Confusão:
# [[ 4  7  1]
#  [ 3 13  4]
#  [ 0  7 23]]
#
# ==================================================
# Modelo: DMC | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000035s | Tempo Médio Teste: 0.002307s
# Acurácia Média:   0.7455 ± 0.0314
# Acurácia Máxima:  0.8072
# Acurácia Mínima:  0.6345
# Acurácia Mediana: 0.7470
#
# Acurácia Média por Classe:
#   - DH: 0.7696
#   - NO: 0.6345
#   - SL: 0.8103
#
# Melhor Matriz de Confusão:
# [[ 29  12   3]
#  [  9  63  10]
#  [  3  11 109]]
#
# Pior Matriz de Confusão:
# [[41  7  1]
#  [43 37  5]
#  [ 6 29 80]]
#
# ==================================================
# Modelo: DMC | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000051s | Tempo Médio Teste: 0.001979s
# Acurácia Média:   0.7477 ± 0.0251
# Acurácia Máxima:  0.8065
# Acurácia Mínima:  0.6820
# Acurácia Mediana: 0.7465
#
# Acurácia Média por Classe:
#   - DH: 0.7734
#   - NO: 0.6586
#   - SL: 0.7987
#
# Melhor Matriz de Confusão:
# [[33  7  3]
#  [11 49  9]
#  [ 2 10 93]]
#
# Pior Matriz de Confusão:
# [[31  7  1]
#  [34 41  4]
#  [ 2 21 76]]
#
# ==================================================
# Modelo: DMC | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000070s | Tempo Médio Teste: 0.001538s
# Acurácia Média:   0.7514 ± 0.0261
# Acurácia Máxima:  0.8129
# Acurácia Mínima:  0.6968
# Acurácia Mediana: 0.7548
#
# Acurácia Média por Classe:
#   - DH: 0.7812
#   - NO: 0.6504
#   - SL: 0.8056
#
# Melhor Matriz de Confusão:
# [[21  7  0]
#  [ 5 43  8]
#  [ 6  3 62]]
#
# Pior Matriz de Confusão:
# [[25  4  1]
#  [21 24  3]
#  [ 6 12 59]]
#
# ==================================================
# Modelo: DMC | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000125s | Tempo Médio Teste: 0.000786s
# Acurácia Média:   0.7581 ± 0.0357
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.6344
# Acurácia Mediana: 0.7581
#
# Acurácia Média por Classe:
#   - DH: 0.7613
#   - NO: 0.6644
#   - SL: 0.8168
#
# Melhor Matriz de Confusão:
# [[13  2  0]
#  [ 5 23  0]
#  [ 4  4 42]]
#
# Pior Matriz de Confusão:
# [[10  7  1]
#  [ 9 16  6]
#  [ 2  9 33]]
#
# ==================================================
# Modelo: DMC | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000060s | Tempo Médio Teste: 0.000566s
# Acurácia Média:   0.7508 ± 0.0538
# Acurácia Máxima:  0.9032
# Acurácia Mínima:  0.6452
# Acurácia Mediana: 0.7419
#
# Acurácia Média por Classe:
#   - DH: 0.7799
#   - NO: 0.6530
#   - SL: 0.8098
#
# Melhor Matriz de Confusão:
# [[10  2  0]
#  [ 1 17  2]
#  [ 0  1 29]]
#
# Pior Matriz de Confusão:
# [[ 8  6  0]
#  [ 8 12  2]
#  [ 3  3 20]]
#
# ==================================================
# Modelo: DMCR | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000104s | Tempo Médio Teste: 0.002011s
# Acurácia Média:   0.7171 ± 0.0240
# Acurácia Máxima:  0.7751
# Acurácia Mínima:  0.6506
# Acurácia Mediana: 0.7189
#
# Acurácia Média por Classe:
#   - DH: 0.6796
#   - NO: 0.5873
#   - SL: 0.8199
#
# Melhor Matriz de Confusão:
# [[41  8  1]
#  [16 56  6]
#  [ 7 18 96]]
#
# Pior Matriz de Confusão:
# [[44  8  0]
#  [39 35  6]
#  [11 23 83]]
#
# ==================================================
# Modelo: DMCR | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000075s | Tempo Médio Teste: 0.001696s
# Acurácia Média:   0.7179 ± 0.0231
# Acurácia Máxima:  0.7696
# Acurácia Mínima:  0.6544
# Acurácia Mediana: 0.7189
#
# Acurácia Média por Classe:
#   - DH: 0.6875
#   - NO: 0.5784
#   - SL: 0.8224
#
# Melhor Matriz de Confusão:
# [[21 15  3]
#  [ 5 48 20]
#  [ 1  6 98]]
#
# Pior Matriz de Confusão:
# [[24 10  4]
#  [30 36 12]
#  [ 4 15 82]]
#
# ==================================================
# Modelo: DMCR | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000070s | Tempo Médio Teste: 0.001385s
# Acurácia Média:   0.7179 ± 0.0263
# Acurácia Máxima:  0.7742
# Acurácia Mínima:  0.6581
# Acurácia Mediana: 0.7194
#
# Acurácia Média por Classe:
#   - DH: 0.6936
#   - NO: 0.5913
#   - SL: 0.8103
#
# Melhor Matriz de Confusão:
# [[26  5  3]
#  [13 36  3]
#  [ 2  9 58]]
#
# Pior Matriz de Confusão:
# [[20 13  2]
#  [15 28  9]
#  [ 0 14 54]]
#
# ==================================================
# Modelo: DMCR | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000065s | Tempo Médio Teste: 0.000841s
# Acurácia Média:   0.7277 ± 0.0412
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.6452
# Acurácia Mediana: 0.7312
#
# Acurácia Média por Classe:
#   - DH: 0.6940
#   - NO: 0.6075
#   - SL: 0.8207
#
# Melhor Matriz de Confusão:
# [[16  3  0]
#  [ 5 13  3]
#  [ 0  4 49]]
#
# Pior Matriz de Confusão:
# [[12  4  1]
#  [15 20  5]
#  [ 5  3 28]]
#
# ==================================================
# Modelo: DMCR | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000116s | Tempo Médio Teste: 0.000496s
# Acurácia Média:   0.7356 ± 0.0589
# Acurácia Máxima:  0.8387
# Acurácia Mínima:  0.5645
# Acurácia Mediana: 0.7419
#
# Acurácia Média por Classe:
#   - DH: 0.7115
#   - NO: 0.6233
#   - SL: 0.8224
#
# Melhor Matriz de Confusão:
# [[11  2  0]
#  [ 2 14  2]
#  [ 1  3 27]]
#
# Pior Matriz de Confusão:
# [[ 3  5  1]
#  [ 8 10  5]
#  [ 2  6 22]]
#
# ==================================================
# Modelo: MaxCorr | Separação (Treino/Teste): 19/80
# ==================================================
# Tempo Médio Treino: 0.000010s | Tempo Médio Teste: 0.000848s
# Acurácia Média:   0.7085 ± 0.0519
# Acurácia Máxima:  0.8072
# Acurácia Mínima:  0.5502
# Acurácia Mediana: 0.7149
#
# Acurácia Média por Classe:
#   - DH: 0.6790
#   - NO: 0.5127
#   - SL: 0.8496
#
# Melhor Matriz de Confusão:
# [[ 27  20   0]
#  [ 12  65   4]
#  [  9   3 109]]
#
# Pior Matriz de Confusão:
# [[46  1  0]
#  [72 14  0]
#  [26 13 77]]
#
# ==================================================
# Modelo: MaxCorr | Separação (Treino/Teste): 30/70
# ==================================================
# Tempo Médio Treino: 0.000020s | Tempo Médio Teste: 0.000774s
# Acurácia Média:   0.7253 ± 0.0432
# Acurácia Máxima:  0.8065
# Acurácia Mínima:  0.5853
# Acurácia Mediana: 0.7327
#
# Acurácia Média por Classe:
#   - DH: 0.7030
#   - NO: 0.5322
#   - SL: 0.8615
#
# Melhor Matriz de Confusão:
# [[25 13  0]
#  [17 54  2]
#  [ 2  8 96]]
#
# Pior Matriz de Confusão:
# [[50  0  0]
#  [71  0  0]
#  [19  0 77]]
#
# ==================================================
# Modelo: MaxCorr | Separação (Treino/Teste): 50/50
# ==================================================
# Tempo Médio Treino: 0.000060s | Tempo Médio Teste: 0.000540s
# Acurácia Média:   0.7277 ± 0.0441
# Acurácia Máxima:  0.8323
# Acurácia Mínima:  0.6065
# Acurácia Mediana: 0.7290
#
# Acurácia Média por Classe:
#   - DH: 0.7264
#   - NO: 0.5536
#   - SL: 0.8465
#
# Melhor Matriz de Confusão:
# [[24 10  0]
#  [ 9 38  1]
#  [ 2  4 67]]
#
# Pior Matriz de Confusão:
# [[26  4  0]
#  [41 14  1]
#  [ 9  6 54]]
#
# ==================================================
# Modelo: MaxCorr | Separação (Treino/Teste): 70/30
# ==================================================
# Tempo Médio Treino: 0.000049s | Tempo Médio Teste: 0.000309s
# Acurácia Média:   0.7357 ± 0.0464
# Acurácia Máxima:  0.8602
# Acurácia Mínima:  0.6129
# Acurácia Mediana: 0.7419
#
# Acurácia Média por Classe:
#   - DH: 0.7448
#   - NO: 0.5456
#   - SL: 0.8554
#
# Melhor Matriz de Confusão:
# [[ 9  6  0]
#  [ 3 24  0]
#  [ 1  3 47]]
#
# Pior Matriz de Confusão:
# [[11  6  0]
#  [24  9  0]
#  [ 2  4 37]]
#
# ==================================================
# Modelo: MaxCorr | Separação (Treino/Teste): 80/20
# ==================================================
# Tempo Médio Treino: 0.000060s | Tempo Médio Teste: 0.000262s
# Acurácia Média:   0.7400 ± 0.0603
# Acurácia Máxima:  0.9032
# Acurácia Mínima:  0.6129
# Acurácia Mediana: 0.7419
#
# Acurácia Média por Classe:
#   - DH: 0.8013
#   - NO: 0.5247
#   - SL: 0.8536
#
# Melhor Matriz de Confusão:
# [[13  0  0]
#  [ 5 10  0]
#  [ 1  0 33]]
#
# Pior Matriz de Confusão:
# [[11  5  0]
#  [11  7  0]
#  [ 4  4 20]]
